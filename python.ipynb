# %%
# !pip install pandas pyodbc matplotlib

# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyodbc
import matplotlib.pyplot as plt


server = 'DESKTOP-4P6OOP1' 
database = 'KxP_hr' 
conn = pyodbc.connect(f'Driver={{SQL Server}};Server={server};Database={database};Trusted_Connection=yes;')
cursor = conn.cursor()

cursor.execute("SELECT price_after_discount, rating_count FROM products WHERE rating_count IS NOT NULL AND price_after_discount IS NOT NULL")
prices = []
reviews = []

for row in cursor.fetchall():
    prices.append(row[0])
    reviews.append(row[1]) 

    plt.scatter(prices, reviews)




plt.title('Price vs Number of Reviews')
plt.xlabel('Price')
plt.ylabel('Review Count')
plt.grid(True)


plt.show()
plt.savefig('my_plot.png', dpi=300, bbox_inches='tight')
